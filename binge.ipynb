# %%
import pandas as pd 
df=pd.read_csv("dataset.csv")
df.head()
# Out:
#     BMI  calories  calories_burnt  Stress Levels  Label
# 0  33.6      1950             181            200      1
# 1  26.6      2600             460            100      2
# 2  27.4      2350             980            400      1
# 3  28.1      1850            1176            100      1
# 4  43.1      2900             560            200      2

# %%
target=df.Label
inputs=df.drop('Label',axis='columns')

# %%
len(inputs)
# Out:
# 24

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
len(X_train)

# %%
len(X_test)
# Out:
# 5

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.predict([[32.4, 1950,1400,300],
[32.8,2600,1470,300],
[34,2350,772,400],
[32.8,1850,643,300],
[30.5,2900,546,300],
[33.7,3100,352,400],
[27.3,2100,393,300],
[37.4,5000,137,200],
[21.9,2400,824,100],
[34.3,6000,1341,300],
[40.6,3000,125,300],
[47.9,1800,140,300],
[50,4200,70,400],
[24.6,1700,100,300],
[25.2,2300,220,300],
[29,3000,220,300],
[40.9,4000,55,100],
[29.7,5400,140,200],
[37.2,4200,40,200],
[44.2,4250,85,100],
[29.7,5050,85,100],
[31.6,6000,67,200],
[29.9,5500,40,400],
[32.5,5800,1000,300],
[29.6,2400,200,200],
[31.9,2450,670,200],
[28.4,3400,505,100],
[30.8,3600,120,200],
[35.4,2000,349,100],
[28.9,2150,587,200],
[43.5,2300,140,200],
[29.7,2800,296,100],
[32.7,2000,193,100],
[31.2,4150,490,100],
[67.1,5400,653,100],
[45,1700,415,300],
[39.1,2100,242,200],
[23.2,2150,1206,300],
[34.9,3250,479,200],
[27.7,4200,460,100],
[26.8,4800,224,100],
[27.6,4600,520,400],
[35.9,1800,473,200],
[30.1,2400,700,200],
[32,2500,1856,100],
[27.9,3800,181,100],
[31.6,2000,460,300],
[22.6,3100,980,200],
[33.1,5200,1176,200],
[30.4,2200,560,300],
[52.3,2100,660,200],
[24.4,1700,800,100],
[39.4,5650,500,400],
[24.3,5900,1220,100],
[22.9,2250,200,200],
[34.8,2350,100,100],
[30.9,2600,1203,100],
[31,5400,1076,100],
[40.1,4400,2500,400],
[27.3,3050,887,100],
[20.4,5900,925,100],
[37.7,2400,515,100],
[23.9,1900,1302,300],
[37.5,2300,800,100],
[37.7,2550,1841,100],
[33.2,2500,1599,100],
[35.5,3800,1143,100],
[27.7,3700,290,200],
[42.8,5800,300,200],
[34.2,2500,1000,200],
[42.6,5150,235,400],
[34.2,4300,128,200],
[41.8,2900,275,200],
[35.8,1500,1583,300],
[30,2200,1254,200],
[29,2200,1248,300],
[37.8,2400,2146,300],
[34.6,3400,1427,300],
[31.6,2900,1841,300],
[25.2,1600,1302,300],
[28.8,4900,1000,300],
[23.6,6450,1781,300],
[34.6,2300,1599,200],
[35.7,2300,1143,300],
[37.2,1800,1018,300],
[36.7,3200,1119,400],
[45.2,3400,347,300],
[44,1900,1009,300],
[46.2,4300,193,300],
[25.4,1800,19,300],
[35,3750,101,300],
[29.7,3500,139,300],
[43.6,2850,164,400],
[35.9,2750,137,200],
[44.1,2950,22,300],
[30.8,7550,17,300],
[18.4,1400,192,300],
[29.2,1550,1716,300],
[33.1,2350,677,300],
[25.6,5400,167,300],
[27.1,3300,16,300],
[38.2,5350,17,300],
[30,5200,32,300],
[31.2,2000,35,200],
[52.3,3550,220,100],
[35.4,2200,116,300],
[30.1,2600,23,300],
[31.2,3700,44,300],
[28,3600,1716,300],
[24.4,2600,86,400],
[35.8,4250,194,300],
[27.6,2050,60,300],
[33.6,5850,121,100],
[30.1,1950,1716,200],
[28.7,5050,1353,200],
[25.9,6200,1069,100],
[33.3,7050,1305,400],
[30.9,2200,227,200],
[30,2350,125,200],
[32.1,5350,243,300],
[32.4,1600,14,200],
[32,3150,39,200],
[33.6,3750,55,100],
[36.3,6400,1151,200],
[40,2000,1220,100],
[25.1,2200,1302,200],
[27.5,2350,720,200],
[45.6,2050,1203,100],
[25.2,3150,1076,100],
[23,4700,1101,100],
[33.2,4100,211,100],
[34.2,2500,1306,300],
[40.5,2400,390,200],
[26.5,2150,395,300],
[27.8,2300,365,200],
[24.9,2800,613,100],
[25.3,9150,352,400],
[37.9,2500,1538,100],
[35.9,2200,290,200],
[32.4,2300,235,200],
[30.4,2400,765,100],
[27,2100,309,100],
[26,2300,799,300],
[38.7,5750,639,200],
[45.6,2950,791,200],
[20.8,1950,1826,300],
[36.1,1900,470,300],
[36.9,1500,95,200],
[36.6,2500,245,100],
[43.3,4000,245,400],
[40.5,500,185,100],
[21.9,690,390,200],
[35.5,2000,330,100],
[28,3000,220,400],
[30.7,3600,1427,100],
[36.6,4000,1841,400],
])
# Out:
# array([1, 1, 1, 1, 2, 2, 1, 3, 1, 3, 2, 1, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 1, 1, 2, 3, 1, 1, 1, 2, 1, 3, 3, 1, 1, 1, 2, 3, 3, 3, 1, 1,
#        1, 3, 1, 2, 3, 1, 1, 1, 3, 3, 1, 1, 1, 3, 3, 2, 3, 1, 1, 1, 3, 1,
#        2, 3, 3, 1, 3, 3, 2, 1, 1, 1, 3, 3, 3, 1, 3, 3, 1, 1, 1, 2, 2, 1,
#        3, 1, 3, 3, 2, 2, 3, 3, 1, 1, 1, 4, 3, 3, 3, 1, 3, 1, 3, 3, 3, 1,
#        3, 1, 3, 1, 3, 3, 3, 1, 1, 4, 1, 3, 3, 3, 1, 1, 1, 1, 2, 3, 3, 1,
#        1, 1, 1, 2, 3, 1, 1, 1, 1, 1, 1, 3, 2, 1, 1, 1, 1, 2, 3, 3, 1, 2,
#        3, 3], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.8

# %%
y_test[:10]

# %%
X_test[:10]

# %%
model.predict(X_test[:10])

# %%
model.predict_proba(X_test[:10])
